# %% [markdown]
# # DaTa science assignmet-7
#
# ## _abhishek_sutar
#
#
# ### 7) Text Analytics
# ### 1. Extract Sample document and apply following document preprocessing methods: Tokenization, POS Tagging, stop words removal, Stemming and Lemmatization.

# %%
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = "Hello everyone! Welcome to my blog post on Medium. We are studying Natural Language Processing.Your choice of font is important, but the kind of “family” you choose is project-specific, and we won’t discuss it here except to make one point: the conventional wisdom among Web designers that only sans-serif fonts are suitable for body text is just a rule of thumb. Although serif fonts, with their greater complexity, may tend to be less effective at small sizes, there are many other factors to consider. A diminutive x-height, for example, could impair the readability of a font from either camp. Some serif fonts are highly legible and attractive for paragraph text if they are set properly. Matthew Carter’s screen-sympathetic Georgia is a case in point."
print(text)
# Out:
# Hello everyone! Welcome to my blog post on Medium. We are studying Natural Language Processing.Your choice of font is important, but the kind of “family” you choose is project-specific, and we won’t discuss it here except to make one point: the conventional wisdom among Web designers that only sans-serif fonts are suitable for body text is just a rule of thumb. Although serif fonts, with their greater complexity, may tend to be less effective at small sizes, there are many other factors to consider. A diminutive x-height, for example, could impair the readability of a font from either camp. Some serif fonts are highly legible and attractive for paragraph text if they are set properly. Matthew Carter’s screen-sympathetic Georgia is a case in point.

# %%
len(text)
# Out:
# 757

# %% [markdown]
# ## 1]Tokenization

# %%
tokens_sents = nltk.sent_tokenize(text)
print(tokens_sents)
# Out:
# ['Hello everyone!', 'Welcome to my blog post on Medium.', 'We are studying Natural Language Processing.Your choice of font is important, but the kind of “family” you choose is project-specific, and we won’t discuss it here except to make one point: the conventional wisdom among Web designers that only sans-serif fonts are suitable for body text is just a rule of thumb.', 'Although serif fonts, with their greater complexity, may tend to be less effective at small sizes, there are many other factors to consider.', 'A diminutive x-height, for example, could impair the readability of a font from either camp.', 'Some serif fonts are highly legible and attractive for paragraph text if they are set properly.', 'Matthew Carter’s screen-sympathetic Georgia is a case in point.']

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', '.', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing.Your', 'choice', 'of', 'font', 'is', 'important', ',', 'but', 'the', 'kind', 'of', '“', 'family', '”', 'you', 'choose', 'is', 'project-specific', ',', 'and', 'we', 'won', '’', 't', 'discuss', 'it', 'here', 'except', 'to', 'make', 'one', 'point', ':', 'the', 'conventional', 'wisdom', 'among', 'Web', 'designers', 'that', 'only', 'sans-serif', 'fonts', 'are', 'suitable', 'for', 'body', 'text', 'is', 'just', 'a', 'rule', 'of', 'thumb', '.', 'Although', 'serif', 'fonts', ',', 'with', 'their', 'greater', 'complexity', ',', 'may', 'tend', 'to', 'be', 'less', 'effective', 'at', 'small', 'sizes', ',', 'there', 'are', 'many', 'other', 'factors', 'to', 'consider', '.', 'A', 'diminutive', 'x-height', ',', 'for', 'example', ',', 'could', 'impair', 'the', 'readability', 'of', 'a', 'font', 'from', 'either', 'camp', '.', 'Some', 'serif', 'fonts', 'are', '
# ...

# %%
from nltk.probability import FreqDist
fdist= FreqDist()

# %%
for word in tokens_words:
    fdist[word.lower()]+=1

print(list(fdist))
fdist
# Out:
# [',', '.', 'are', 'to', 'of', 'is', 'a', 'the', 'fonts', 'for', 'we', 'font', 'and', '’', 'point', 'text', 'serif', 'hello', 'everyone', '!', 'welcome', 'my', 'blog', 'post', 'on', 'medium', 'studying', 'natural', 'language', 'processing.your', 'choice', 'important', 'but', 'kind', '“', 'family', '”', 'you', 'choose', 'project-specific', 'won', 't', 'discuss', 'it', 'here', 'except', 'make', 'one', ':', 'conventional', 'wisdom', 'among', 'web', 'designers', 'that', 'only', 'sans-serif', 'suitable', 'body', 'just', 'rule', 'thumb', 'although', 'with', 'their', 'greater', 'complexity', 'may', 'tend', 'be', 'less', 'effective', 'at', 'small', 'sizes', 'there', 'many', 'other', 'factors', 'consider', 'diminutive', 'x-height', 'example', 'could', 'impair', 'readability', 'from', 'either', 'camp', 'some', 'highly', 'legible', 'attractive', 'paragraph', 'if', 'they', 'set', 'properly', 'matthew', 'carter', 's', 'screen-sympathetic', 'georgia', 'case', 'in']
# ...

# %% [markdown]
# ## 2]stop words removal

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
without_stopwords = [w for w in tokens_words if not w in stop_words]
without_stopwords
# Out:
# ['Hello',
#  'everyone',
#  '!',
#  'Welcome',
#  'blog',
#  'post',
#  'Medium',
#  '.',
#  'We',
#  'studying',
#  'Natural',
#  'Language',
#  'Processing.Your',
#  'choice',
#  'font',
#  'important',
#  ',',
#  'kind',
#  '“',
#  'family',
#  '”',
#  'choose',
#  'project-specific',
#  ',',
#  '’',
#  'discuss',
#  'except',
#  'make',
#  'one',
#  'point',
#  ':',
#  'conventional',
#  'wisdom',
#  'among',
#  'Web',
#  'designers',
#  'sans-serif',
#  'fonts',
#  'suitable',
#  'body',
#  'text',
#  'rule',
#  'thumb',
#  '.',
#  'Although',
#  'serif',
#  'fonts',
#  ',',
#  'greater',
#  'complexity',
#  ',',
#  'may',
#  'tend',
#  'less',
#  'effective',
#  'small',
#  'sizes',
#  ',',
#  'many',
#  'factors',
#  'consider',
#  '.',
#  'A',
#  'diminutive',
#  'x-height',
#  ',',
#  'example',
#  ',',
#  'could',
#  'impair',
#  'readability',
#  'font',
#  'either',
#  'camp',
#  '.',
#  'Some',
#  'serif',
#  'fonts',
#  'highly',
#  'legible',
#  'attractive',
# ...

# %% [markdown]
# ## removing punctuation

# %%
# pp=[]
# import re
# punctuation=re.compiler(r'[-.?!,:;|0-9]')
# string = without_stopwords

# for words in string:
    
#     without_stop_punctution = punctuation.sub("", words)

#     if len(without_stop_punctution)>0:
#         pp.append(without_stop_punctution)

# %% [markdown]
# # 3]Stemming and Lemmatization

# %%
import nltk

from nltk.stem import SnowballStemmer
from nltk.stem.porter import PorterStemmer
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# #words to stem
words = without_stopwords
# ps = PorterStemmer()
# #Stemming the words
# for word in words:
#     print(word+' -> '+ ps.stem(words))

snowball = SnowballStemmer(language='english')

for word in words:
    print(word,"--->",snowball.stem(word))
# Out:
# Hello ---> hello
# everyone ---> everyon
# ! ---> !
# Welcome ---> welcom
# blog ---> blog
# post ---> post
# Medium ---> medium
# . ---> .
# We ---> we
# studying ---> studi
# Natural ---> natur
# Language ---> languag
# Processing.Your ---> processing.your
# choice ---> choic
# font ---> font
# important ---> import
# , ---> ,
# kind ---> kind
# “ ---> “
# family ---> famili
# ” ---> ”
# choose ---> choos
# project-specific ---> project-specif
# , ---> ,
# ’ ---> ’
# discuss ---> discuss
# except ---> except
# make ---> make
# one ---> one
# point ---> point
# : ---> :
# conventional ---> convent
# wisdom ---> wisdom
# among ---> among
# Web ---> web
# designers ---> design
# sans-serif ---> sans-serif
# fonts ---> font
# suitable ---> suitabl
# body ---> bodi
# text ---> text
# rule ---> rule
# thumb ---> thumb
# . ---> .
# Although ---> although
# serif ---> serif
# fonts ---> font
# , ---> ,
# greater ---> greater
# complexity ---> complex
# , ---> ,
# may ---> may
# ...

# %%
lemmatizer = WordNetLemmatizer()

# %%
# # Lemmatize single word
# # 
# print(lemmatizer.lemmatize("workers"))
# print(lemmatizer.lemmatize("beeches"))

# %%
words = without_stopwords

word_list = words

print(word_list)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'blog', 'post', 'Medium', '.', 'We', 'studying', 'Natural', 'Language', 'Processing.Your', 'choice', 'font', 'important', ',', 'kind', '“', 'family', '”', 'choose', 'project-specific', ',', '’', 'discuss', 'except', 'make', 'one', 'point', ':', 'conventional', 'wisdom', 'among', 'Web', 'designers', 'sans-serif', 'fonts', 'suitable', 'body', 'text', 'rule', 'thumb', '.', 'Although', 'serif', 'fonts', ',', 'greater', 'complexity', ',', 'may', 'tend', 'less', 'effective', 'small', 'sizes', ',', 'many', 'factors', 'consider', '.', 'A', 'diminutive', 'x-height', ',', 'example', ',', 'could', 'impair', 'readability', 'font', 'either', 'camp', '.', 'Some', 'serif', 'fonts', 'highly', 'legible', 'attractive', 'paragraph', 'text', 'set', 'properly', '.', 'Matthew', 'Carter', '’', 'screen-sympathetic', 'Georgia', 'case', 'point', '.']

# %%
# lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
# print(lemmatized_output)
for word in word_list:
    y=lemmatizer.lemmatize(word)
    print(word,"--->",y)
# Out:
# Hello ---> Hello
# everyone ---> everyone
# ! ---> !
# Welcome ---> Welcome
# blog ---> blog
# post ---> post
# Medium ---> Medium
# . ---> .
# We ---> We
# studying ---> studying
# Natural ---> Natural
# Language ---> Language
# Processing.Your ---> Processing.Your
# choice ---> choice
# font ---> font
# important ---> important
# , ---> ,
# kind ---> kind
# “ ---> “
# family ---> family
# ” ---> ”
# choose ---> choose
# project-specific ---> project-specific
# , ---> ,
# ’ ---> ’
# discuss ---> discus
# except ---> except
# make ---> make
# one ---> one
# point ---> point
# : ---> :
# conventional ---> conventional
# wisdom ---> wisdom
# among ---> among
# Web ---> Web
# designers ---> designer
# sans-serif ---> sans-serif
# fonts ---> font
# suitable ---> suitable
# body ---> body
# text ---> text
# rule ---> rule
# thumb ---> thumb
# . ---> .
# Although ---> Although
# serif ---> serif
# fonts ---> font
# , ---> ,
# greater ---> greater
# complexity ---> complexity
# , ---> ,
# ...

# %% [markdown]
# ## 4]Pos Tagging

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', '.', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing.Your', 'choice', 'of', 'font', 'is', 'important', ',', 'but', 'the', 'kind', 'of', '“', 'family', '”', 'you', 'choose', 'is', 'project-specific', ',', 'and', 'we', 'won', '’', 't', 'discuss', 'it', 'here', 'except', 'to', 'make', 'one', 'point', ':', 'the', 'conventional', 'wisdom', 'among', 'Web', 'designers', 'that', 'only', 'sans-serif', 'fonts', 'are', 'suitable', 'for', 'body', 'text', 'is', 'just', 'a', 'rule', 'of', 'thumb', '.', 'Although', 'serif', 'fonts', ',', 'with', 'their', 'greater', 'complexity', ',', 'may', 'tend', 'to', 'be', 'less', 'effective', 'at', 'small', 'sizes', ',', 'there', 'are', 'many', 'other', 'factors', 'to', 'consider', '.', 'A', 'diminutive', 'x-height', ',', 'for', 'example', ',', 'could', 'impair', 'the', 'readability', 'of', 'a', 'font', 'from', 'either', 'camp', '.', 'Some', 'serif', 'fonts', 'are', '
# ...

# %%
    
for token in tokens_words:
    print(nltk.pos_tag([token]))
    

     
    # Word tokenizers is used to find the words
    # and punctuation in a string
    #wordsList = nltk.word_tokenize(i)

 
    #  Using a Tagger. Which is part-of-speech
    # tagger or POS-tagger.

#print("Parts of Speech: ",nltk.pos_tag(y))
# Out:
# [('Hello', 'NN')]
# [('everyone', 'NN')]
# [('!', '.')]
# [('Welcome', 'VB')]
# [('to', 'TO')]
# [('my', 'PRP$')]
# [('blog', 'NN')]
# [('post', 'NN')]
# [('on', 'IN')]
# [('Medium', 'NN')]
# [('.', '.')]
# [('We', 'PRP')]
# [('are', 'VBP')]
# [('studying', 'VBG')]
# [('Natural', 'JJ')]
# [('Language', 'NN')]
# [('Processing.Your', 'NN')]
# [('choice', 'NN')]
# [('of', 'IN')]
# [('font', 'NN')]
# [('is', 'VBZ')]
# [('important', 'JJ')]
# [(',', ',')]
# [('but', 'CC')]
# [('the', 'DT')]
# [('kind', 'NN')]
# [('of', 'IN')]
# [('“', 'NN')]
# [('family', 'NN')]
# [('”', 'NN')]
# [('you', 'PRP')]
# [('choose', 'NN')]
# [('is', 'VBZ')]
# [('project-specific', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('we', 'PRP')]
# [('won', 'NN')]
# [('’', 'NN')]
# [('t', 'NN')]
# [('discuss', 'NN')]
# [('it', 'PRP')]
# [('here', 'RB')]
# [('except', 'IN')]
# [('to', 'TO')]
# [('make', 'VB')]
# [('one', 'CD')]
# [('point', 'NN')]
# [(':', ':')]
# [('the', 'DT')]
# [('conventional', 'JJ')]
# ...

# %% [markdown]
# ## word cloud

# %%
# Create and generate a word cloud image:

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2. Create representation of documents by calculating Term Frequency and Inverse DocumentFrequency.

# %%
# import required module
from sklearn.feature_extraction.text import TfidfVectorizer

# assign documents
doc1 = 'Term Frequency: In document d, the frequency represents the number of instances of a given word t. Therefore, we can see that it becomes more relevant when a word appears in the text, which is rational. Since the ordering of terms is not significant, we can use a vector to describe the text in the bag of term models. For each specific term in the paper, there is an entry with the value being the term frequency.'
doc2 = 'Document Frequency: This tests the meaning of the text, which is very similar to TF, in the whole corpus collection. The only difference is that in document d, TF is the frequency counter for a term t, while df is the number of occurrences in the document set N of the term t. In other words, the number of papers in which the word is present is DF.'
doc3 = 'Inverse Document Frequency: Mainly, it tests how relevant the word is. The key aim of the search is to locate the appropriate records that fit the demand. Since tf considers all terms equally significant, it is therefore not only possible to use the term frequencies to measure the weight of the term in the paper. First, find the document frequency of a term t by counting the number of documents containing the term:'

# merge documents into a single corpus
string = [doc1, doc2, doc3]

# create object
tfidf = TfidfVectorizer()

# get tf-df values
result = tfidf.fit_transform(string)

# get idf values
print('\nidf values:')
for ele1, ele2 in zip(tfidf.get_feature_names_out(), tfidf.idf_):
    print(ele1, ':', ele2)

# get indexing
print('\nWord indexes:')
print(tfidf.vocabulary_)

# display tf-idf values
print('\ntf-idf value:')
print(result)

# in matrix form
print('\ntf-idf values in matrix form:')
print(result.toarray())
# Out:
# idf values:
# aim : 1.6931471805599454
# all : 1.6931471805599454
# an : 1.6931471805599454
# appears : 1.6931471805599454
# appropriate : 1.6931471805599454
# bag : 1.6931471805599454
# becomes : 1.6931471805599454
# being : 1.6931471805599454
# by : 1.6931471805599454
# can : 1.6931471805599454
# collection : 1.6931471805599454
# considers : 1.6931471805599454
# containing : 1.6931471805599454
# corpus : 1.6931471805599454
# counter : 1.6931471805599454
# counting : 1.6931471805599454
# demand : 1.6931471805599454
# describe : 1.6931471805599454
# df : 1.6931471805599454
# difference : 1.6931471805599454
# document : 1.0
# documents : 1.6931471805599454
# each : 1.6931471805599454
# entry : 1.6931471805599454
# equally : 1.6931471805599454
# find : 1.6931471805599454
# first : 1.6931471805599454
# fit : 1.6931471805599454
# for : 1.2876820724517808
# frequencies : 1.6931471805599454
# frequency : 1.0
# given : 1.6931471805599454
# how : 1.6931471805599454
# in : 1.0
# ...
