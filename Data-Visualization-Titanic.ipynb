# %% [markdown]
# #  DS ASSIGNMENT-8
#
# ## _Abhishek_Sutar
#
# ## Data Visualization I
# ### 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we can find any patterns in the data.
# ### 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
#Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading the dataset

df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1 = df.drop(['deck'], axis=1)

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1['age'].fillna(int(df1['age'].mean()), inplace=True)

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df1.shape
# Out:
# (889, 14)

# %%
#Plotting a DistPlot

sns.distplot(df1['fare'])
# Out:
# /home/admin1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
#Plotting a JointPlot

sns.jointplot(x='age', y='fare', data=df1)

# %%
#Plotting a BarPlot

sns.barplot(x='sex', y='age', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a CountPlot

sns.countplot(x='sex', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#Plotting a BoxPlot

sns.boxplot(x='sex', y='age', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a BoxPlot with hue as Survived

sns.boxplot(x='sex', y='age', data=df1, hue="survived")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a ViolinPlot

sns.violinplot(x='sex', y='age', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a ViolinPlot with hue as Survived

sns.violinplot(x='sex', y='age', data=df1, hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a BoxPlot with hue as Survived and split as true

sns.violinplot(x='sex', y='age', data=df1, hue='survived', split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a StripPlot

sns.stripplot(x='sex', y='age', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Plotting a StripPlot with hue as Survived and split as true

sns.stripplot(x='sex', y='age', data=df1, jitter=True, hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#Combining a ViolinPlot and a SwarmPlot

sns.violinplot(x='sex', y='age', data=df1)
sns.swarmplot(x='sex', y='age', data=df1, color='black')
# Out:
# /home/admin1/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 18.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/admin1/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='age'>
# /home/admin1/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/admin1/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 13.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Plotting a Histogram with x as 'fare'

sns.distplot(df['fare'])
# Out:
# /home/admin1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# <AxesSubplot:xlabel='fare', ylabel='Density'>
